# %% [markdown]
# # Calling all set operators
# Congratulations! You've now made your way to the challenge problem for this chapter. Test your knowledge of set operators in SQL by classifying the below use cases into the correct buckets.
#
# Think of how the information in each use case could be stored as tables, and recall the Venn diagrams you have learned, shown below!
#
#
# !["Set Theory 01"](<set_theory_01.png>)
#
#
# ## Instructions
# 1. Drag and drop the use cases provided into the correct set operator.
#
# ## Table
#
# |Item|UNION or UNION ALL|INTERSECT|EXCEPT|
# |---|---|---|---|
# |A residence hall has asked students to rank their preferences to be assigned to a room. They now want to pair students based on their common preferences| |X| |
# |You run a music streaming service and have a list of songs a user has listened to. You want to show them new songs they haven't heard before| | |X|
# |You are a school teacher teaching multiple classes. You would like to combine the grades of all students into one consolidated sheet|X| | |
