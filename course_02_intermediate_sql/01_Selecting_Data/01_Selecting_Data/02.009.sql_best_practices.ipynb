# %% [markdown]
# # SQL best practices
#
# SQL style guides outline standard best practices for writing code.
#
# This exercise will present several SQL style tips. Your job will be to decide whether they are considered best practices.
#
# We'll be following Holywell's style guide.
#
# ## Instructions
# Drag and drop the items into the correct zone.
#
# ## Table
# |Items|Best Practice|Poor Practice|
# |---|---|---|
# |Capitalize keywords|X| |
# |Write lots of queries with no semicolon| |X|
# |Write the query on one line| |X|
# |Don't capitalize keywords| |X|
# |Use underscores in our names rather than spaces|X| |
# |End queries with a semicolon|X| |
